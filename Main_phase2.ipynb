# %% [markdown]
#  Project Phase 2
#
#  Note: Please note that we have refined our dataset from Phase 1 by enhancing the data cleaning processes to achieve a more accurate dataset.

# %% [markdown]
# ### Team Members

# %% [markdown]
# #### Anchal Daga - 50609480
# #### Keerthana Vangala - 50604773
# #### Grace Evangelene Avula Lael - 50595809
# #### Sharanya Nallapeddi - 50593866

# %% [markdown]
# ## Task 1:

# %% [markdown]
# #### Title: Leveraging health data to predict infant survival and wellbeing from pregnancy to early childhood.

# %% [markdown]
# #### Problem Statement:
# This project seeks to address the challenge of improving maternal and infant health outcomes by utilizing data-driven insights. The core problem lies in identifying key factors that influence infant survival rates and overall well being, from pregnancy through early childhood. Factors like birth rates, vaccination coverage, teen pregnancies, low birth weights, maternal age, pre-existing conditions, and access to prenatal care can all affect outcomes. However, healthcare systems often struggle to predict and allocate resources efficiently to areas in need.
# By analyzing datasets from reliable sources, such as the CDC, and developing predictive models, this project aims to provide insights that will help healthcare providers and policymakers optimize resources, including vaccines, and identify regions where additional healthcare interventions are critical.

# %% [markdown]
# #### Potential Contribution:
# This project has the potential to make a significant contribution by creating a predictive framework that healthcare providers and policymakers can use to anticipate and respond to the needs of specific populations. By identifying high-risk areas—such as regions with elevated rates of teen pregnancies, low birth weights, or limited prenatal care—this model can guide the distribution of critical healthcare resources, including vaccines and maternal support services.
# More specifically, the insights generated could help allocate resources more efficiently, such as predicting the number of vaccines required in a community, targeting interventions to reduce infant mortality, and identifying maternal health risks earlier. By focusing on actionable data points like vaccination rates and access to care, this project could empower local healthcare systems to address disparities, reduce preventable deaths, and enhance the overall health and wellbeing of mothers and infants during these crucial stages of life. These insights are vital to creating a more responsive and equitable healthcare infrastructure, especially in underserved or vulnerable regions.

# %% [markdown]
# #### Contribution Effectiveness:
# 1. Early Risk Identification: Health data allows for early detection of risks in mothers and infants, leading to timely interventions that improve outcomes.
# 2. Efficient Resource Allocation: Data insights help target resources like vaccines and prenatal care to high-risk regions, reducing healthcare disparities.
# 3. Reducing Preventable Deaths: Predictive models anticipate complications early, allowing for interventions that can prevent infant deaths.
# 4. Empowering Decision-Makers: Data-driven insights enable healthcare providers and policymakers to make informed, resource-efficient decisions.
# 5. Promoting Healthcare Equity: Predictive data ensures that vulnerable and underserved populations receive adequate healthcare resources.
# 6. Enhancing Long-Term Outcomes: Early risk detection leads to better long-term health outcomes for both mothers and infants, fostering healthier communities

# %% [markdown]
# ## Task 2

# %% [markdown]
# ### Anchal Daga - 50609480

# %% [markdown]
# ### Question 1: Does the incidence of anemia in pregnant women connect with the prevalence of anemia in newborns, and how is this relationship impacted by maternal nutrition programs or availability to qualified medical personnel?
# Variety of Hypotheses:
#
# Hypothesis 1:
#
# A higher prevalence of anemia among pregnant women will correlate with an increased prevalence of anemia in infants.
#
# Explanation:
#
# This may be due to inadequate iron transfer during pregnancy, indicating a direct link between maternal health and infant outcomes.
#
# Hypothesis 2:
#
# In a region, those with greater percentages of deliveries attended by experienced health workers would display lower rates of anemia in infants.
#
# Explanation:
#
#  This can suggest that enhanced maternal care and nutrition directly contribute to better iron status in newborns.
#
# Significance of the question:
#
# This issue is important because it has the potential to reveal the connections between the health of mothers and infants, especially in relation to anemia, a condition that can have major effects on both the mother and the child. Determining if maternal anemia causes a higher incidence of anemia in babies can provide important information on the first causes of health inequalities.

# %% [markdown]
# ### Question 2: What is the relationship between hospital infrastructure and the rates of stillbirths and neonatal deaths in different nations?
#
# Hypothesis 1 :
#
# In the China, higher hospital resources will be associated with lower rates of neonatal deaths and stillbirths.
#
# Explanation:
#
# This is indicating that enhanced healthcare infrastructure and access to skilled birth attendants contribute to better maternal and infant health outcomes.
#
#
# Hypothesis 2:
#
# In Ghana, higher hospital resources will be associated with lower rates of neonatal deaths and stillbirths.
#
# Explanation:
#
# While an increase in healthcare resources, such as nurses, midwives, and hospital facilities, is generally expected to lower neonatal deaths and stillbirths, the relationship in Ghana may be influenced by other factors.
#
# Significance of the question:
#
# The significance of this question lies in understanding the crucial role of healthcare infrastructure in reducing neonatal deaths and stillbirths, which are key indicators of a nation's overall health system performance. It is feasible to evaluate the effects of disparate hospital resource levels, including the availability of nurses, midwives, and healthcare facilities, on birth outcomes by contrasting nations, such as China and Ghana.

# %% [markdown]
# ### Keerthana Vangala - 50604773

# %% [markdown]
# #### Question 1. What is the association between immunization coverage ( HepB, Polio, BCG) and infant mortality?
# Objective:
#
# Understanding the correlation between baby mortality rates and immunization coverage (HepB, Polio, BCG) can yield insights into the effects of vaccination on infant survival. This might be one of the critical factors that impacts infant's well-being.
#
# Significance: Immunization are crucial for preventing illnesses that frequently result in newborn death, particularly those related to Hepatitis B (HepB), Polio, and BCG. These illnesses have the potential to sharply raise infant mortality rates in the absence of adequate vaccination coverage. Additionally, this will also mean that health care facilities allocate resources and budget for vaccinating the infants and to take this seriously
#
# Hypothesis 1: Higher immunization rates for HepB, Polio, and BCG are linked with lower infant mortality rates. If this is correct it means that vaccination given in the 1st one year to a baby are protecting them against the respective diseases.
#
# Hypothesis 2: Regions with higher immunization records will tend to have lower infant mortality rate?
#
# Question 2:
#
# How does low birth weight correlate outcomes in infants' health and infant mortality?
#
#
# Alignment with Objective:
#
# Low birth weight is an important factor which be affecting the short term and long-term health of the baby. This will also depict how early birth conditions are having a weightage on baby’s survival rate. We can know if child is facing any health complications or getting to affect to diseases or having conditions like low immunization
#
#
# Significance:
#
# Infants with low birth weight (approx 2,500 grams) are at a higher risk of neonatal mortality and infant mortality. Understanding this will help the medical facilities to take better care of the baby by taking all the measures in order to protect the baby. Care should be taken not only in the initial phase but also in the later phases of the baby's life. Mother can actually get to know about babies' condition even before baby is born. She should take additional care when doctor says that the weight of baby might be less.
#
# Hypothesis 1:
#
# Compared to normal birth weight, low birth weight is linked to a higher risk of infant mortality.
#
#
# Hypothesis 2:
#
# Is there any correlation between babies with lower weight and attendants taking care of the baby?

# %% [markdown]
# ### Grace Evangelene Avula Lael - 50595809

# %% [markdown]
# #### Question 1 : Does the availability of adequate healthcare resources reduce maternal and infant mortality rate?
# Relevance to objective :
# This question directly aligns with the project's primary objective of identifying key factors that influence maternal and infant health outcomes. By exploring the relationship between healthcare resource availability—such as the number of healthcare professionals, access to skilled staff during childbirth, and immunization rates—and mortality rates, the project aims to uncover critical insights that can guide resource allocation and improve healthcare systems. The hypotheses emphasize measurable aspects of healthcare resources, making it possible to analyze their impact systematically. Understanding these relationships is vital for developing targeted interventions that address preventable deaths, ultimately enhancing health outcomes for mothers and infants.
#
# Hypothesis:
#
# -	An increased number of physicians and trained healthcare professionals, such as nurses and midwives, is linked to lower maternal mortality rates.
#
# -	The presence of skilled health staff during childbirth, along with sufficient hospital bed capacity, significantly reduces both maternal and infant mortality rates.
#
# -	Greater access to prenatal care is associated with decreased maternal mortality.
#
# -	Higher rates of immunization among infants are associated with reduced infant mortality rates.
#
# -	Higher prevalence of intermittent preventive treatment (IPT) of malaria in pregnancy among pregnant women correlates with lower maternal mortality rates.
#
# -	Increased coverage of vitamin A supplementation among children correlates with lower rates of infant mortality.
#
# Significance:
# These hypotheses explore various dimensions of healthcare resources and their effects on maternal and infant health outcomes. By investigating these relationships, we can identify critical factors that contribute to mortality rates. This understanding can inform targeted interventions and policies aimed at improving healthcare systems, ultimately reducing preventable deaths and enhancing health for mothers and infants globally.

# %% [markdown]
# #### Question 2: How does women literacy rate influence healthcare during pregnancy and the child’s life?
# Relevance to objective : This question supports the objective of leveraging health data to improve maternal and child health by highlighting the role of women's literacy in shaping healthcare behaviors and outcomes. The proposed hypotheses demonstrate how literacy can affect vital health-related actions, such as ensuring vaccinations, accessing prenatal care, and reducing high-risk behaviors. By examining these connections, the project can inform policies and interventions aimed at increasing women's literacy as a means of enhancing health outcomes. This focus on education underscores the broader societal implications of maternal and infant health, indicating that empowering women through education can lead to better health practices and ultimately lower mortality rates. Additionally, by analyzing indicators related to anemia and child mortality, this question enables a data-driven assessment of the intersection between education, health behaviors, and healthcare access, providing a pathway for targeted healthcare interventions in regions of need.
#
# Hypothesis:
#
# -	In communities with higher literacy rates, mothers are more particular about ensuring their children receive vaccinations, leading to improved immunization rates.
#
# -	Higher literacy rates among women are associated with lower engagement in high-risk behaviours, such as tobacco use, during pregnancy.
#
# -	with higher education levels are more likely to prioritize and access prenatal care, resulting in increased percentages of pregnant women receiving adequate prenatal visits, including at least four check-ups due to enhanced understanding of the importance of prenatal care for maternal and child health.
#
# -	Countries with a higher literacy rate among women exhibit lower maternal mortality ratios.
#
# -	Higher literacy rates among women are linked to increased postnatal care coverage, which is crucial for monitoring maternal and infant health after childbirth.
#
# -	Regions with higher literacy rates among women show reduced prevalence of anemia in pregnant women, leading to lower maternal and infant mortality rates.
#
# Significance:
# These hypotheses underscore the critical role that women's literacy plays in influencing healthcare behaviors and outcomes during pregnancy and early childhood. By understanding the connections between education and health practices, policymakers and health organizations can design targeted interventions to improve maternal and child health. Investing in female education not only enhances individual well-being but can also lead to broader public health improvements, ultimately reducing maternal and infant mortality rates.

# %% [markdown]
# ### Sharanya Nallapeddi - 50593866

# %% [markdown]
# #### 1. Is there a correlation between the prevalence of anemia in children and the number of child deaths?
# Relevance to Objective:
#
# By analyzing key risk factors like anemia, this hypothesis directly contributes to the goal of employing data-driven insights to optimise mother and child health outcomes.  The dataset includes indicators that can be used to determine if areas with high rates of anemia also have higher rates of child deaths. These indicators include child mortality, healthcare access, and anemia prevalence (as determined by nutrition-related or health metrics). This would allow a data-driven assessment of the need for healthcare resources, such as nutritional therapies, and help develop a predictive model that pinpoints regions in need of further medical assistance.
#
# Significance:
#
# Strong correlations suggest that anemia has a major role in influencing child mortality. Taking care of these conditions would have a direct influence on healthcare planning, directing initiatives such as nutrition programs and anemia screening in areas where anemia prevalence is high. A key data-driven insight that could help authorities allocate resources more effectively would be the capacity to forecast child mortality based on the prevalence of anemia. By addressing a fundamental health issue influencing child mortality in different regions, this advances the project's objective of optimizing mother and child health outcomes.
# Hypothesis
#
# Hypothesis 1: The likelihood of child mortality increases with the prevalence of anemia in children.
#
# Impact: In order to lower child mortality, it would be essential to address anemia as a serious health risk and highlight the need for early intervention programs and nutrition improvement initiatives.
#
# Hypothesis 2: The correlation between infant anemia prevalence and infant mortality is substantially lower in areas with high levels of socioeconomic development and maternal education.
#
# Impact: This hypothesis suggests that improved living conditions, better nutrition, and easier access to healthcare can mitigate the negative effects of anemia on child mortality. Specifically, higher levels of maternal education and socioeconomic development may have a protective role in this regard. This would emphasise the significance of concentrating on broader socioeconomic policies targeting at raising maternal education and living standards in addition to direct health interventions in order to lower anemia-related child death rates.

# %% [markdown]
# #### 2. How does maternal hypertension correlate with low birthweight and infant mortality?
# Relevance to Objective:
#
# Healthcare statistics show that maternal hypertension plays a significant role in determining infant mortality as well as delivery outcomes. The dataset can be used to investigate this correlation because it contains information on infant death rates, low birthweight statistics, and maternal health indicators. Through an understanding of this relationship, the study will be able predict the areas where high maternal hypertension rates are likely leading to higher infant mortality and worse birth outcomes. This information is crucial for predicting the need for healthcare services (such as prenatal care and programs to manage hypertension) and making sure that resources are distributed to the most vulnerable areas.
#
# Significance:
#
# The need for focused healthcare treatments, such as improved prenatal care and hypertension screening programs for expectant mothers, is highlighted if there's a clear correlation between maternal hypertension and low birthweight and infant mortality. This question is important because it enables medical professionals to concentrate on maternal health as a predictor of adverse birth outcomes, which is in line with the project's goal of allocating healthcare resources as efficiently as possible. The project's objective of enhancing maternal and baby health outcomes through predictive models will be directly supported by identifying regions with high incidence of maternal hypertension, which will assist policymakers and healthcare professionals in identifying and avoiding infant mortality.
#
#
# Hypothesis 1: Increased maternal hypertension is strongly  related with higher rates of low birthweight and infant mortality
# rates.
#
# Impact: The need for comprehensive maternal healthcare programs particularly for the management of hypertension during pregnancy would be reinforced if this hypothesis holds true. And, this may result in higher expenditures on prenatal care and managing hypertension in order to lower low birthweight and infant mortality.
#
# Hypothesis 2: Exposure to maternal healthcare services serves as a mediating factor in the correlation between low birthweight/infant mortality and maternal hypertension.
#
# Impact: Assuming this theory proves accurate, it implies that access to healthcare services (such as monitoring, medication, and prenatal care) can mitigate the association between maternal hypertension and unfavourable birth outcomes. As a result, measures that boost maternal healthcare access would be necessary to reduce the risks of pregnancy-related hypertension.

# %% [markdown]
# ## Task 3

# %% [markdown]
# ####  Data Retrieval:
# 1.	Finding relevant information for our project and analysis was the first step in the data retrieval process. Initially, we were able to acquire the data from the worldbank.org webpage, which employed 470 distinct statistical data parameters based on geographic area over a period of time.
# 2.	Given the extensive nature of the assessed dataset, we then tried to decipher features that were suitable for completing our objective.
# 3.	We selected 48 features from among the 470 distinct characteristic features that were pertinent to our issue. They included factors like diabetes prevalence, hypertension, and lifestyle choices, which are linked to maternal health risks. For infant health, features like low-birthweight, infant and neonatal mortality rates, and immunization coverage were considered. We also included healthcare infrastructure indicators, such as hospital beds and availability of healthcare staff, to provide a comprehensive view of maternal and infant well being across different countries.
# 4.	The following features were then combined to form a dataset that could be used to analyze and give insights into our problem statement.

# %%
import pandas as pd

# %%
import os
import warnings
warnings.filterwarnings('ignore')

# %%
#load the data from the local folder
file_path = '/Users/sharanya/Downloads/Raw_Data_Updated.csv' 

dataset = pd.read_csv(file_path)

print(dataset.head())
# Out:
#      Region Name Region Code  Year Year Code  \
# 0  United States         USA  2004    YR2004
# 1  United States         USA  2005    YR2005
# 2  United States         USA  2006    YR2006
# 3  United States         USA  2007    YR2007
# 4  United States         USA  2008    YR2008
#
#   Birth rate, crude (per 1,000 people) [SP.DYN.CBRT.IN]  \
# 0                                                 14
# 1                                                 14
# 2                                               14.3
# 3                                               14.3
# 4                                                 14
#
#   Births attended by skilled health staff (% of total) [SH.STA.BRTC.ZS]  \
# 0                                               99.3
# 1                                               99.4
# 2                                               99.4
# 3                                               99.3
# 4                                               99.3
#
# ...

# %%
pip install qgrid
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Task 4

# %% [markdown]
# #### Step 1: Removing Duplicates:
#
# - Before evaluating the data, it is essential to remove duplicate entries from the dataset.
# - Such data can lead to misleading insights and incorrect conclusions, which may affect the quality of any analysis or modeling performed.
# - We found multiple region-specific repetitive values in our dataset, which might bias our findings by assigning those repeated entries an excessive amount of weight.
# - For example, if a region was included more than once with the same measurements, this could imply that it has a higher significance in the dataset.
# - We carefully found and eliminated these duplicates to assure the integrity of our analysis, resulting in a cleaner dataset.
# - This reduces possible noise and confusion in the data, which improves the accuracy of our conclusions while also making additional research easier.
# This is achieved by using the .drop_duplicates() function from the pandas library, which effectively removes duplicate entries from the dataset, ensuring the integrity and accuracy of our analysis.

# %%
#Data Cleaning
#Step 1 :  Remove duplicates rows

dataset.drop_duplicates(keep='first', inplace=True)

file_path = './Remove_Duplicate_Rows.csv' 
#dataset.to_csv(file_path, index=False)
dataset.head()
# Out:
#      Region Name Region Code  Year Year Code  \
# 0  United States         USA  2004    YR2004
# 1  United States         USA  2005    YR2005
# 2  United States         USA  2006    YR2006
# 3  United States         USA  2007    YR2007
# 4  United States         USA  2008    YR2008
#
#   Birth rate, crude (per 1,000 people) [SP.DYN.CBRT.IN]  \
# 0                                                 14
# 1                                                 14
# 2                                               14.3
# 3                                               14.3
# 4                                                 14
#
#   Births attended by skilled health staff (% of total) [SH.STA.BRTC.ZS]  \
# 0                                               99.3
# 1                                               99.4
# 2                                               99.4
# 3                                               99.3
# 4                                               99.3
#
# ...

# %% [markdown]
# #### Step 2 : Removing Irrelevant Columns:
# We examined the dataset during data preprocessing and found a few columns that were not significantly useful to the study as a whole.
#
# The "year code" column was one example, which, following analysis, was discovered to have no effect on the model's results or the conclusions we sought to draw.
#
# Maintaining such columns could add complexity and complicate data processing, causing computational lag and make it more difficult to see trends.
#
# We simplified our dataset by getting rid of these unnecessary columns.
#
# We are hence able to concentrate on the other important characteristics that inform our study.
#
# This is accomplished using the .drop() : (df.drop(columns=['Year Code'], inplace=True) ) function from the pandas library, which allows us to remove unnecessary columns from the dataset, simplifying our analysis and focusing on key features.

# %%
#Data Cleaning
#Step 2 : Remove irrelevant column like Year Code
print(dataset.columns)
dataset.columns = dataset.columns.str.strip()
dataset.drop(columns=['Year Code'], errors='ignore', inplace=True)
for col in dataset.columns:
    print(col)

file_path = '~/Downloads/remove_irrelevant_columns_dataset.csv'
#dataset.to_csv(file_path, index=False)
# Out:
# Index(['Region Name', 'Region Code', 'Year', 'Year Code',
#        'Birth rate, crude (per 1,000 people) [SP.DYN.CBRT.IN]',
#        'Births attended by skilled health staff (% of total) [SH.STA.BRTC.ZS]',
#        'Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total) [SH.DTH.COMM.ZS]',
#        'Death rate, crude (per 1,000 people) [SP.DYN.CDRT.IN]',
#        'Diabetes prevalence (% of population ages 20 to 79) [SH.STA.DIAB.ZS]',
#        'Hospital beds (per 1,000 people) [SH.MED.BEDS.ZS]',
#        'Immunization, BCG (% of one-year-old children) [SH.IMM.IBCG]',
#        'Immunization, HepB3 (% of one-year-old children) [SH.IMM.HEPB]',
#        'Immunization, measles second dose (% of children by the nationally recommended age) [SH.IMM.MEA2]',
#        'Immunization, Pol3 (% of one-year-old children) [SH.IMM.POL3]',
#        'Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women) [SH.MLR.IPTP.ZS]',
# ...

# %% [markdown]
# #### Step 3 : Removing Irrelevant rows:
# One of the most important steps in the data cleaning process is eliminating unnecessary rows from a dataset.
#
# It guarantees that the study concentrates solely on the relevant points, enhancing the quality and reliability of the outcomes.
#
# This method cuts down on complexity and processing time while improving the clarity and accuracy of your findings.
#
# This is accomplished using the .drop() function from the pandas library (e.g., df.drop(index=~all_irrelevant_rows, inplace=True)), enabling us to remove irrelevant rows and streamline our dataset for more focused analysis.
#
# Irrelevant rows to remove:
#     Blanks,
#     Fragile and conflict affected situations,
#     Heavily indebted poor countries (HIPC),
#     high income,
#     IBRD only,
#     IDA & IBRD total,
#     IDA blend,
#     IDA only,
#     IDA total,
#     last updated: 07/01/2024,
#     late demographic dividend,
#     Low & middle income,
#     least developed countries: UN classified,
#     Low income,
#     low & middle income,
#     Lower middle income,
#     Not classified,
#     OECD members,
#     other small states,
#     post demographic dividend ,
#     pre demographic dividend,
#     South asia(ida & IBRD),
#     upper middle income,
#     World

# %%
#Data Cleaning
#Step 3 : Remove irrelevant data

unwanted_regions = [ '', 'Fragile and conflict affected situations', 'Heavily indebted poor countries (HIPC)', 'High income', 'IBRD only', 'IDA & IBRD total', 'IDA blend', 'IDA only', 'IDA total', 'Late-demographic dividend', 'Early-demographic dividend', 'Post-demographic dividend', 'Pre-demographic dividend', 'Low & middle income', 'Least developed countries: UN classification', 'Low income', 'Lower middle income', 'Not classified', 'OECD members', 'Other small states', 'South Asia (IDA & IBRD)', 'Upper middle income', 'World' ]

dataset_cleaned = dataset[~dataset['Region Name'].isin(unwanted_regions)] 

file_path = '~/Downloads/remove_rows_unwanted_regions_dataset.csv'
# dataset_cleaned.to_csv(file_path, index=False)

dataset_cleaned.head()
# Out:
#      Region Name Region Code  Year  \
# 0  United States         USA  2004
# 1  United States         USA  2005
# 2  United States         USA  2006
# 3  United States         USA  2007
# 4  United States         USA  2008
#
#   Birth rate, crude (per 1,000 people) [SP.DYN.CBRT.IN]  \
# 0                                                 14
# 1                                                 14
# 2                                               14.3
# 3                                               14.3
# 4                                                 14
#
#   Births attended by skilled health staff (% of total) [SH.STA.BRTC.ZS]  \
# 0                                               99.3
# 1                                               99.4
# 2                                               99.4
# 3                                               99.3
# 4                                               99.3
#
# ...

# %%
print(dataset_cleaned.columns)
# Out:
# Index(['Region Name', 'Region Code', 'Year',
#        'Birth rate, crude (per 1,000 people) [SP.DYN.CBRT.IN]',
#        'Births attended by skilled health staff (% of total) [SH.STA.BRTC.ZS]',
#        'Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total) [SH.DTH.COMM.ZS]',
#        'Death rate, crude (per 1,000 people) [SP.DYN.CDRT.IN]',
#        'Diabetes prevalence (% of population ages 20 to 79) [SH.STA.DIAB.ZS]',
#        'Hospital beds (per 1,000 people) [SH.MED.BEDS.ZS]',
#        'Immunization, BCG (% of one-year-old children) [SH.IMM.IBCG]',
#        'Immunization, HepB3 (% of one-year-old children) [SH.IMM.HEPB]',
#        'Immunization, measles second dose (% of children by the nationally recommended age) [SH.IMM.MEA2]',
#        'Immunization, Pol3 (% of one-year-old children) [SH.IMM.POL3]',
#        'Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women) [SH.MLR.IPTP.ZS]',
# ...

# %% [markdown]
# #### Step 5 : Handling Negative Values:
#  Inconsistencies in the data could lead to negative numbers, or there could be legitimate negative values when temperatures are involved.
#
# Since there are no negative values in any of the columns in this dataset, we removed all negative values from it in order to maintain data consistency.
#
# To achieve this, we use the condition (df[numeric_cols] >= 0).all(axis=1) to filter the DataFrame and remove any rows that have negative values in the numeric columns.

# %%
print(dataset_cleaned.columns)
# Out:
# Index(['Region Name', 'Region Code', 'Year',
#        'Birth rate, crude (per 1,000 people) [SP.DYN.CBRT.IN]',
#        'Births attended by skilled health staff (% of total) [SH.STA.BRTC.ZS]',
#        'Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total) [SH.DTH.COMM.ZS]',
#        'Death rate, crude (per 1,000 people) [SP.DYN.CDRT.IN]',
#        'Diabetes prevalence (% of population ages 20 to 79) [SH.STA.DIAB.ZS]',
#        'Hospital beds (per 1,000 people) [SH.MED.BEDS.ZS]',
#        'Immunization, BCG (% of one-year-old children) [SH.IMM.IBCG]',
#        'Immunization, HepB3 (% of one-year-old children) [SH.IMM.HEPB]',
#        'Immunization, measles second dose (% of children by the nationally recommended age) [SH.IMM.MEA2]',
#        'Immunization, Pol3 (% of one-year-old children) [SH.IMM.POL3]',
#        'Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women) [SH.MLR.IPTP.ZS]',
# ...

# %%
#Data cleaning
# Step 5 - Handling Negative Values

column_names = [
    'Life expectancy at birth, female (years) [SP.DYN.LE00.FE.IN]',
    'Number of infant deaths, female [SH.DTH.IMRT.FE]',
    'Number of maternal deaths [SH.MMR.DTHS]',
    'Number of stillbirths [SH.DTH.STLB]'
]

# Convert each column to numeric, forcing errors to NaN for non-numeric values
for column_name in column_names:
    dataset_cleaned.loc[:, column_name] = pd.to_numeric(dataset_cleaned[column_name], errors='coerce')

# Filter out rows where any of the columns have negative values
dataset_cleaned2 = dataset_cleaned[(dataset_cleaned[column_names] >= 0).all(axis=1)]
# Save the cleaned dataset to a new file
file_path = '~/Downloads/handling_negatives.csv'
dataset_cleaned2.to_csv(file_path, index=False)

# Output the cleaned file path
print(f"Cleaned dataset saved to: {file_path}")
# Out:
# Cleaned dataset saved to: ~/Downloads/handling_negatives.csv

# %%
# !pip install scikit-learn
# Out:
# zsh:1: command not found: pip

# %%
import sklearn
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# #### Step 6 : Standardizing Categorical Data:
# The process of standardizing categorical data involves converting numeric representations (like region codes) from categorical values (like region names).
#
# Since many algorithms work better with numerical inputs, giving each zone a unique number helps data analysis using statistical or machine learning models.
#
# The information contained in the categories is preserved but comparisons and calculations are made simpler due to this change.

# %%
#Data cleaning
#Step 6 - Standardizing Categorical Data
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

dataset_cleaned2['Region Code Numeric'] = label_encoder.fit_transform(dataset_cleaned2['Region Code'])
region_code_mapping = dict(zip(label_encoder.classes_, range(len(label_encoder.classes_))))

print("Region Code Mapping:")
print(region_code_mapping)

file_path = '~/Downloads/standardized_region_code.csv'
dataset_cleaned2.to_csv(file_path, index=False)

# Display the first few rows of the updated dataset
print(dataset_cleaned2.head())
# Out:
# Region Code Mapping:
# ...

# %%
import re

# %% [markdown]
# #### Step 7 : Convert Year to Datetime:
# The year is converted to a datetime object in order to make time-related data processing simpler.
#
# It makes sure that the "year" column is interpreted as a datetime object, which makes it possible to perform simple time series analysis, including trend analysis, date-based filtering, and time interval calculations.
#
# The usefulness of the dataset is improved by this conversion, providing deeper insights into the connections present in the data.
#
# This is accomplished by converting the 'Year' column to datetime format using pd.to_datetime() while keeping only the year information (e.g., df['Year'] = pd.to_datetime(df['Year'].astype(str), format='%Y')).

# %%
#Data cleaning
#Step 7 - Converting Year to Date time

# Convert 'Year' to datetime but ensure only the year part is preserved
dataset_cleaned2['Year'] = pd.to_datetime(dataset_cleaned2['Year'], errors='coerce', format='%Y').dt.year


print(dataset_cleaned2.head())
# Out:
#      Region Name Region Code  Year  \
# 1  United States         USA  2005
# 2  United States         USA  2006
# 3  United States         USA  2007
# 4  United States         USA  2008
# 5  United States         USA  2009
#
#   Birth rate, crude (per 1,000 people) [SP.DYN.CBRT.IN]  \
# 1                                                 14
# 2                                               14.3
# 3                                               14.3
# 4                                                 14
# 5                                               13.5
#
#   Births attended by skilled health staff (% of total) [SH.STA.BRTC.ZS]  \
# 1                                               99.4
# 2                                               99.4
# 3                                               99.3
# 4                                               99.3
# 5                                               99.3
#
# ...

# %% [markdown]
# #### Step 8 : Renaming Columns:
# Renaming columns in a dataset is done to improve its meaning, description, or readability.
#
# Additionally, it could help in standardization, guaranteeing consistency among diverse datasets.
#
# A few columns in this dataset contain codes like [SP.DYN.CBRT.IN]. These columns have been renamed since they are unnecessary for the overall data analyses.
#
# Additionally, some column names contain whitespaces between their titles. We resorted to inserting an underscore instead of a whitespace for easy access and uniformity.
#
# This is achieved by using str.replace() with regex patterns to replace spaces with underscores and to remove text within square brackets from the column names (e.g., df.columns.str.replace(r'\s+', '_', regex=True) and df.columns.str.replace(r'\s*\[.*?\]', '', regex=True))

# %%
#Data cleaning
#Step 8 - Renaming columns

# Clean the column names
dataset_cleaned2.columns = dataset_cleaned2.columns.str.replace(r'\s*\[.*?\]', '', regex=True) 
dataset_cleaned2.columns = dataset_cleaned2.columns.str.replace('_', ' ')

file_path = '~/Downloads/Modified.csv'
dataset_cleaned2.to_csv(file_path, index=False)

print(dataset_cleaned2.columns.tolist())
# Out:
# ['Region Name', 'Region Code', 'Year', 'Birth rate, crude (per 1,000 people)', 'Births attended by skilled health staff (% of total)', 'Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total)', 'Death rate, crude (per 1,000 people)', 'Diabetes prevalence (% of population ages 20 to 79)', 'Hospital beds (per 1,000 people)', 'Immunization, BCG (% of one-year-old children)', 'Immunization, HepB3 (% of one-year-old children)', 'Immunization, measles second dose (% of children by the nationally recommended age)', 'Immunization, Pol3 (% of one-year-old children)', 'Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)', 'Life expectancy at birth, female (years)', 'Life expectancy at birth, male (years)', 'Life expectancy at birth, total (years)', 'Lifetime risk of maternal death (%)', 'Lifetime risk of maternal death (1 in: rate varies by country)', 'Literacy rate, Pregnant Women (% of pregnant women ages 15 and 
# ...

# %%
import numpy as np

# %% [markdown]
# STEP 9: DATA CLEANING
#
# -- 70 %
#
#
# --- LESS THAN 70%

# %%
# data cleaning
invalid_value = ".."

# Calculate the percentage of 'invalid' values per column
invalid_percentage = (dataset_cleaned2 == invalid_value).sum() / len(dataset_cleaned2) * 100

# Identify columns to drop (where invalid percentage is more than 80%)
columns_to_drop = invalid_percentage[invalid_percentage > 84].index

# Drop the identified columns
data_cleaned_step1 = dataset_cleaned2.drop(columns=columns_to_drop)

# Display or save the cleaned dataset
print(f"Columns dropped: {list(columns_to_drop)}")
data_cleaned_step1.to_csv('cleaned_file.csv', index=False)
print(len(columns_to_drop))
# Out:
# Columns dropped: ['Diabetes prevalence (% of population ages 20 to 79)', 'Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)', 'Postnatal care coverage (% mothers)', 'Pregnant women receiving prenatal care of at least four visits (% of pregnant women)']
# 4

# %%
# Infant Mortality Rate to Birth Rate Ratio


# Convert the columns to numeric, forcing errors to NaN (if necessary)
data_cleaned_step1["Mortality rate, infant (per 1,000 live births)"] = pd.to_numeric(data_cleaned_step1["Mortality rate, infant (per 1,000 live births)"], errors='coerce')
data_cleaned_step1["Birth rate, crude (per 1,000 people)"] = pd.to_numeric(data_cleaned_step1["Birth rate, crude (per 1,000 people)"], errors='coerce')

# Now perform the division
data_cleaned_step1["Infant Mortality Rate to Birth Rate Ratio"] = data_cleaned_step1["Mortality rate, infant (per 1,000 live births)"] / data_cleaned_step1["Birth rate, crude (per 1,000 people)"]

# Save to CSV
data_cleaned_step1.to_csv("cleaned_file_1.csv", index=False)

# %%
# Extract the relevant column names for regions and the "Infant Mortality Rate to Birth Rate Ratio"
region_column = 'Region Name'
ratio_column = 'Infant Mortality Rate to Birth Rate Ratio'

# Create a copy of the data to avoid modifying the first 3 columns
data_modified = data_cleaned_step1.copy()

# List of columns that should not be modified (first 3 columns)
unmodifiable_columns = data_modified.columns[:3]

# Modify the function to handle non-numeric or missing data more robustly
def replace_dot_dot_values(data, region_column, ratio_column):
    regions = data[region_column].unique()

    for region in regions:
        # Subset data for the current region
        region_data = data[data[region_column] == region]
        
        for column in data.columns:
            if column not in unmodifiable_columns and column != region_column and column != ratio_column:
                # Get total number of ".." in the column for the region
                region_dot_dot_count = (region_data[column] == "..").sum()
                region_total_count = region_data.shape[0]
                region_dot_dot_percentage = (region_dot_dot_count / region_total_count) * 100

                # If ".." is more than 70% of the data for the region
                if region_dot_dot_percentage > 70:
                    # Find a region with a similar Infant Mortality to Birth Rate Ratio
                    current_region_ratio = data.loc[data[region_column] == region, ratio_column].replace("..", pd.NA).astype(float).mean()
                    
                    # Find regions with similar ratios (within a certain range)
                    similar_region = data[(data[region_column] != region) &
                                          (abs(data[ratio_column].replace("..", pd.NA).astype(float) - current_region_ratio) < 0.05)]
                    
                    if not similar_region.empty:
                        # Replace ".." with the mean of the similar region's column value (handling non-numeric values)
                        try:
                            replacement_value = pd.to_numeric(similar_region[column], errors='coerce').mean()
                            data.loc[data[region_column] == region, column] = data.loc[data[region_column] == region, column].replace("..", replacement_value)
                        except:
                            pass
                else:
                    # Replace ".." with the mean of the column for that particular region (handling non-numeric values)
                    try:
                        region_mean_value = pd.to_numeric(region_data[column], errors='coerce').mean()
                        data.loc[data[region_column] == region, column] = data.loc[data[region_column] == region, column].replace("..", region_mean_value)
                    except:
                        pass

# Apply the modified replacement function
replace_dot_dot_values(data_modified, region_column, ratio_column)

data_modified.to_csv('cleaned_file_5.csv', index=False)

# %% [markdown]
# #### Step : 10: Feature Engineering:
# Health Infrastructure Index: Combine hospital beds, nurses, and physicians per 1,000 people to assess healthcare availability. This index reflects the overall health infrastructure of each country.
#
# Immunization Coverage Score: Aggregate immunization rates for BCG, HepB3, measles, and Pol3 to calculate overall vaccination coverage. This score indicates the effectiveness of immunization programs in each country.
#
#
# Maternal and Infant Health Risk Index: Combine maternal mortality ratio, infant mortality rate, and neonatal mortality rate to create a composite risk score. This index quantifies the health risks faced by mothers and infants.
#
# Maternal Health Care Access Index: Combine percentages of pregnant women receiving prenatal care and postnatal care, including four or more visits. This index evaluates access to comprehensive maternal healthcare services.
#
# Birth-Death Ratio: Calculate the ratio of crude birth rate to crude death rate. This metric assesses demographic balance and population growth potential.
#
# Life Expectancy Variability: Determine the difference between female and male life expectancy. This measure highlights gender health disparities and informs targeted health interventions.

# %%
# Data cleaning
# Step 10 - Feature Engineering

# Convert relevant columns to numeric, forcing errors to NaN
cols_to_convert = [
    'Birth rate, crude (per 1,000 people)',
    'Death rate, crude (per 1,000 people)',
    'Immunization, HepB3 (% of one-year-old children)',
    'Immunization, measles second dose (% of children by the nationally recommended age)',
    'Life expectancy at birth, female (years)',
    'Life expectancy at birth, male (years)',
    'Mortality rate, infant (per 1,000 live births)',
    'Mortality rate, neonatal (per 1,000 live births)',
    'Prevalence of hypertension, pregnant women (% of pregnant women adults ages 30-79)',
    'Mortality rate, infant, female (per 1,000 live births)',
    'Mortality rate, infant, male (per 1,000 live births)',
    'Maternal mortality ratio (modeled estimate, per 100,000 live births)'
]

dataset_cleaned2 = data_modified.copy()

# Convert the columns to numeric
for col in cols_to_convert:
    dataset_cleaned2[col] = pd.to_numeric(dataset_cleaned2[col], errors='coerce')

# Birth-Death Ratio
dataset_cleaned2['Birth-Death Ratio'] = dataset_cleaned2['Birth rate, crude (per 1,000 people)'] / dataset_cleaned2['Death rate, crude (per 1,000 people)']

# Avg of HepB3 and Measles second dose immunization rates
dataset_cleaned2['Immunization Efficacy'] = (dataset_cleaned2['Immunization, HepB3 (% of one-year-old children)'] + 
                                             dataset_cleaned2['Immunization, measles second dose (% of children by the nationally recommended age)']) / 2

# Life Expectancy Difference
dataset_cleaned2['Life Expectancy Difference'] = dataset_cleaned2['Life expectancy at birth, female (years)'] - dataset_cleaned2['Life expectancy at birth, male (years)']

# Infant Mortality Rate to Birth Rate Ratio
# dataset_cleaned2['Infant Mortality Rate to Birth Rate Ratio'] = dataset_cleaned2['Mortality rate, infant (per 1,000 live births)'] / dataset_cleaned2['Birth rate, crude (per 1,000 people)']

# Neonatal Mortality Rate to Birth Rate Ratio
dataset_cleaned2['Neonatal Mortality Rate to Birth Rate Ratio'] = dataset_cleaned2['Mortality rate, neonatal (per 1,000 live births)'] / dataset_cleaned2['Birth rate, crude (per 1,000 people)']

# Hypertension to Birth Rate Ratio
dataset_cleaned2['Hypertension to Birth Rate Ratio'] = dataset_cleaned2['Prevalence of hypertension, pregnant women (% of pregnant women adults ages 30-79)'] / dataset_cleaned2['Birth rate, crude (per 1,000 people)']

# Female to Male Infant Mortality
dataset_cleaned2['Female to Male Infant Mortality'] = dataset_cleaned2['Mortality rate, infant, female (per 1,000 live births)'] / dataset_cleaned2['Mortality rate, infant, male (per 1,000 live births)']

# Maternal to Neonatal Mortality
dataset_cleaned2['Maternal to Neonatal Mortality'] = dataset_cleaned2['Maternal mortality ratio (modeled estimate, per 100,000 live births)'] / dataset_cleaned2['Mortality rate, neonatal (per 1,000 live births)']

# Handle potential infinite or NaN values (for cases where division by zero occurs)
dataset_cleaned2.replace([float('inf'), -float('inf')], pd.NA, inplace=True)

# Save the cleaned and engineered dataset to a new file
file_path = '~/Downloads/feature_engineering.csv'
dataset_cleaned2.to_csv(file_path, index=False)

# Output some of the cleaned data
print(dataset_cleaned2.head())
# Out:
#      Region Name Region Code  Year  Birth rate, crude (per 1,000 people)  \
# 1  United States         USA  2005                                  14.0
# 2  United States         USA  2006                                  14.3
# 3  United States         USA  2007                                  14.3
# 4  United States         USA  2008                                  14.0
# 5  United States         USA  2009                                  13.5
#
#   Births attended by skilled health staff (% of total)  \
# 1                                               99.4
# 2                                               99.4
# 3                                               99.3
# 4                                               99.3
# 5                                               99.3
#
#   Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total)  \
# 1                                           7.562206
# ...

# %% [markdown]
# #### Step 11: Handling outliers:
# The interquartile range (IQR) is used by the quartile technique to find values that deviate from the typical data range in order to address outliers.
#
# To enhance data integrity, outliers—values that fall noticeably below or above usual data values—can be eliminated or modified.
#
# This is achieved by defining a function to calculate the IQR, identify outliers beyond 1.5 times the IQR, and replace them with the median (e.g., df[col].apply(lambda x: median_value if x < lower_bound or x > upper_bound else x)).

# %%
#Data Cleaning
#Step 11 - Handling outliers

numeric_cols = dataset_cleaned2.select_dtypes(include=['float64', 'int64']).columns

def handle_outliers_iqr(dataset_cleaned2, col):
    Q1 = dataset_cleaned2[col].quantile(0.25)
    Q3 = dataset_cleaned2[col].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    median_value = dataset_cleaned2[col].median()

    # Replace outliers with the median value using .loc to avoid the warning
    dataset_cleaned2.loc[(dataset_cleaned2[col] < lower_bound) | (dataset_cleaned2[col] > upper_bound), col] = median_value

for col in numeric_cols:
    handle_outliers_iqr(dataset_cleaned2, col)

file_path = '~/Downloads/cleaned_dataset_outliers.csv'
dataset_cleaned2.to_csv(file_path, index=False)

# Display the first few rows of the cleaned dataset
dataset_cleaned2.head()
# Out:
#      Region Name Region Code  Year  Birth rate, crude (per 1,000 people)  \
# 1  United States         USA  2005                                  14.0
# 2  United States         USA  2006                                  14.3
# 3  United States         USA  2007                                  14.3
# 4  United States         USA  2008                                  14.0
# 5  United States         USA  2009                                  13.5
#
#   Births attended by skilled health staff (% of total)  \
# 1                                               99.4
# 2                                               99.4
# 3                                               99.3
# 4                                               99.3
# 5                                               99.3
#
#   Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total)  \
# 1                                           7.562206
# ...

# %% [markdown]
# Step 12: rounding off all decimal values upto 2 decimal points

# %%
# Step 12: rounding off decimal points

# Function to truncate to 2 decimal places without rounding
def truncate_to_two_decimals(x):
    return np.floor(x * 100) / 100

# Select all columns starting from the 4th column onward (index 3 since Python uses 0-based indexing)
numeric_cols = dataset_cleaned2.iloc[:, 3:]

# Convert to numeric and truncate values to 2 decimal places without rounding
dataset_cleaned2.iloc[:, 3:] = numeric_cols.apply(pd.to_numeric, errors='coerce').applymap(truncate_to_two_decimals)

# Save the updated DataFrame to a CSV file
file_path = '~/Downloads/cleaned_dataset_rounded_off.csv'
dataset_cleaned2.to_csv(file_path, index=False)

# %%
beautify_data = dataset_cleaned2.head(100)

numeric_cols = beautify_data.select_dtypes(include=['number'])

styled_data = beautify_data.style.set_properties(**{
    'border': '1px solid black',
    'color': 'black',
    'background-color': '#f4f4f9',
    'text-align': 'center',
}).set_table_styles([{
    'selector': 'thead th',
    'props': [('background-color', '#55608f'), ('color', 'white'), ('font-size', '12px')]
}])

styled_data = styled_data.highlight_max(subset=numeric_cols.columns, color='lightgreen').highlight_min(subset=numeric_cols.columns, color='lightcoral')

from IPython.display import display

display(styled_data)
# Out:
# <style type="text/css">
# #T_86132 thead th {
#   background-color: #55608f;
#   color: white;
#   font-size: 12px;
# }
# ...
